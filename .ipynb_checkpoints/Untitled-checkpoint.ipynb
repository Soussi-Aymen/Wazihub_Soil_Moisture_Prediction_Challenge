# %% [markdown]
# # Wazihub Soil Moisture Prediction Challenge

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# Import data

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Aymen\\Desktop\\Wazihub Soil Moisture Prediction Challenge'

# %%
maize = pd.read_csv('Context_Data_Maize.csv')
peanuts = pd.read_csv('Context_Data_Peanuts.csv')
sample = pd.read_csv('SampleSubmission.csv')
train = pd.read_csv('Train.csv')
var_defs = pd.read_csv('/VariableDefinitions.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-401f73fc7688> in <module>
#       3 sample = pd.read_csv('SampleSubmission.csv')
#       4 train = pd.read_csv('Train.csv')
# ----> 5 var_defs = pd.read_csv('/VariableDefinitions.csv')
#
# ...

# %%
train.head()
# Out:
#              timestamp  Soil humidity 1  Irrigation field 1  Soil humidity 2  \
# 0  2019-02-23 00:00:00            67.92                 0.0            55.72
# 1  2019-02-23 00:05:00            67.89                 0.0            55.74
# 2  2019-02-23 00:10:00            67.86                 0.0            55.77
# 3  2019-02-23 00:15:00            67.84                 0.0            55.79
# 4  2019-02-23 00:20:00            67.81                 0.0            55.82
#
#    Irrigation field 2  Soil humidity 3  Irrigation field 3  Soil humidity 4  \
# 0                 0.0            -1.56                 1.0            26.57
# 1                 0.0            -1.51                 1.0            26.58
# 2                 0.0            -1.47                 1.0            26.59
# 3                 0.0            -1.42                 1.0            26.61
# 4                 0.0            -1.38                 1.0            26.62
#
# ...

# %%
sample.head()
# Out:
#                                       ID  Values
# 0  2019-03-25 22:50:00 x Soil humidity 1     NaN
# 1  2019-03-25 22:55:00 x Soil humidity 1     NaN
# 2  2019-03-25 23:00:00 x Soil humidity 1     NaN
# 3  2019-03-25 23:05:00 x Soil humidity 1     NaN
# 4  2019-03-25 23:10:00 x Soil humidity 1     NaN

# %%
maize.head()
# Out:
#      Date  Min_Temp  Max_Temp  Humidity  Wind_Speed  Solar_Irradiance  Sun  \
# 0   6-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 1   7-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 2   8-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 3   9-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 4  10-Feb       NaN       NaN       NaN         NaN               NaN  NaN
#
#     Kc  ETc  ETo  Rainfall  Water_Need_1day  Water_Need_2days  \
# 0  0.4  NaN  NaN       0.0              NaN               NaN
# 1  0.4  NaN  NaN       0.0              NaN               NaN
# 2  0.4  NaN  NaN       0.0              NaN               NaN
# 3  0.4  NaN  NaN       0.0              NaN               NaN
# 4  0.4  NaN  NaN       0.0              NaN               NaN
#
#    Water_Need_3days
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
peanuts.head()
# Out:
#      Date  Min_Temp  Max_Temp  Humidity  Wind_Speed  Solar_Irradiance  Sun  \
# 0   6-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 1   7-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 2   8-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 3   9-Feb       NaN       NaN       NaN         NaN               NaN  NaN
# 4  10-Feb       NaN       NaN       NaN         NaN               NaN  NaN
#
#     Kc  ETc  ETo  Rainfall  Water_Need_1day  Water_Need_2days  \
# 0  0.4  NaN  NaN       0.0              0.0               NaN
# 1  0.4  NaN  NaN       0.0              0.0               NaN
# 2  0.4  NaN  NaN       0.0              0.0               NaN
# 3  0.4  NaN  NaN       0.0              0.0               NaN
# 4  0.4  NaN  NaN       0.0              0.0               NaN
#
#    Water_Need_3days  Unnamed: 14
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# ...

# %%
var_defs
# Out:
#    Variabe Definitions                                         Unnamed: 1
# 0                  NaN                                                NaN
# 1                Train                                                NaN
# 2            timestamp          Time of recording in yyyy-mmm-dd hh-mm-ss
# 3      Soil_humidity_1                           Soil humidity of field 1
# 4   Irrigation field 1                  1=irrigation on, 0=irrigation off
# 5      Soil_humidity_2                           Soil humidity of field 2
# 6   Irrigation field 2                  1=irrigation on, 0=irrigation off
# 7      Soil_humidity_3                           Soil humidity of field 3
# 8   Irrigation field 3                  1=irrigation on, 0=irrigation off
# 9      Soil_humidity_4                           Soil humidity of field 4
# 10  Irrigation field 4                  1=irrigation on, 0=irrigation off
# 11     Air_temperature           Temprature of the air in degrees Celcius
# ...

# %%
train["timestamp"] = pd.to_datetime(train["timestamp"])
train.set_index("timestamp", inplace=True)

# %%
train.loc["2019-05-28":"2019-05-31"]["Irrigation field 4"].unique()
# Out:
# array([ 0.,  1., nan])
